# %%
# 1. Import required libraries and read the dataset and retrieve top 5 and bottom 5 records.
import pandas as pd
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('youtube_dislike_dataset.csv')
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
# Display the first 5 rows of the DataFrame
df.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
# Display the last 5 rows of the DataFrame
df.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %%
# 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %% [markdown]
# * Shape of the dataframe is Rows 37422 and column 12 the major data type of the column is object

# %%
df.shape
# Out:
# (37422, 12)

# %%
# 3. Check for the Percentage of the missing values and drop or impute them.
(df.isnull().sum())/len(df)*100

# As isnull() is the bolean function so we used sum here to count the number of the missing values
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
# There is some missing values in comments column and these are in very low percentage and comment is categorical 
# so we can not add some comments in blank rows so we are droping these
df = df.dropna()
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
# 4. Check the statistical summary of both numerical and categorical columns and write your inferences. 
df.describe(include='int')

# Statistical summary of numerical columns
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.726400e+04  3.726400e+04  3.726400e+04   3.726400e+04
# mean   5.710821e+06  1.672867e+05  4.996434e+03   9.966953e+03
# std    2.431304e+07  5.384931e+05  3.075194e+04   1.173465e+05
# min    2.036800e+04  2.200000e+01  3.000000e+00   1.000000e+00
# 25%    5.141305e+05  1.331725e+04  2.827500e+02   9.140000e+02
# 50%    1.321860e+06  4.255600e+04  7.980000e+02   2.347000e+03
# 75%    3.674527e+06  1.309665e+05  2.466250e+03   6.212000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
# Summary statistics of categorical columns
df.describe(include='object')
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37264  37264                     37264                37264
# unique        37264  36958                     10891                10813
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description  \
# count                 37264  37264       37264
# unique                36617  28705       35479
# top     2020-10-16 04:00:10
# freq                      6   3808         587
#
#                                                  comments
# count                                               37264
# unique                                              37264
# top     Respect to Dortmund fans,must be sad losing hi...
# freq                                                    1

# %%
# 5. Convert datatype of column published_at from object to pandas datetime.
df['published_at']=pd.to_datetime(df['published_at'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37264 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37264 non-null  object
#  1   title          37264 non-null  object
#  2   channel_id     37264 non-null  object
#  3   channel_title  37264 non-null  object
#  4   published_at   37264 non-null  datetime64[ns]
#  5   view_count     37264 non-null  int64
#  6   likes          37264 non-null  int64
#  7   dislikes       37264 non-null  int64
#  8   comment_count  37264 non-null  int64
#  9   tags           37264 non-null  object
#  10  description    37264 non-null  object
#  11  comments       37264 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 3.7+ MB

# %%
# 6. Create a new column as 'published_month' using the column published_at (display the months only)
df['published_month'] = df['published_at'].dt.month
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
# 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'and so on.....
df['published_month']=df['published_at'].apply(lambda x:x.month_name())
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
# 8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count
df.groupby('published_month')['video_id'].count().sort_values(ascending=False)
# Out:
# published_month
# October      4976
# September    4854
# November     4821
# August       4250
# December     3063
# July         2331
# June         2305
# March        2248
# February     2125
# April        2119
# January      2099
# May          2073
# Name: video_id, dtype: int64

# %%
# 9. Find the count of unique video_id, channel_id and channel_title.
df['video_id'].nunique()
# Out:
# 37264

# %%
df['channel_id'].nunique()
# Out:
# 10891

# %%
df['channel_title'].nunique()
# Out:
# 10813

# %%
# 10.Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.
df.groupby('channel_title')['video_id'].count().sort_values(ascending=False).head(10)
# Out:
# channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: video_id, dtype: int64

# %%
df.groupby('channel_title')['video_id'].count().sort_values(ascending=False).tail(10)
# Out:
# channel_title
# Karikku Tuned      1
# Karen Bustillos    1
# Karen Aslanyan     1
# Karchez            1
# Karate Combat      1
# Kaptain Kuba       1
# Kanye West         1
# Kannur kitchen     1
# Kannada Cinema     1
# zoom               1
# Name: video_id, dtype: int64

# %%
# 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.
df[df['likes']==df['likes'].max()]
# Out:
#           video_id                          title                channel_id  \
# 26143  gdZLi9oWNZg  BTS () 'Dynamite' Official MV  UC3IZKseVpdzPSBaWxBxundA
#
#       channel_title        published_at  view_count     likes  dislikes  \
# 26143   HYBE LABELS 2020-08-21 03:58:10  1322796924  31837675   1814333
#
#        comment_count                   tags  \
# 26143       16071029  BIGHIT   BTS BANGTAN
#
#                                              description  \
# 26143  BTS () 'Dynamite' Official MV\n\n\nCredits:\nD...
#
#                                                 comments published_month
# 26143  Armys, we will strive for the mv to reach 100 ...          August

# %%
# Title of video with minimum likes
df[df['likes']==df['likes'].min()]
# Out:
#           video_id                          title                channel_id  \
# 23855  cfP1eeNPT_E  Leading the Charge | Circle K  UC7kPuM7FmDnHjJHvJIPJP_Q
#
#       channel_title        published_at  view_count  likes  dislikes  \
# 23855      Circle K 2021-02-07 06:37:52     2254615     22         9
#
#        comment_count                                               tags  \
# 23855             12  Circle K EVs Electric Vehicles General Motors ...
#
#                                              description  \
# 23855  As stated by our fearless leader, were bringin...
#
#                                                 comments published_month
# 23855  This amazing seeing the future cleaner and mor...        February

# %%
# 12. Find the title of the video which has the maximum number of dislikes and the title of the video having
# minimum dislikes and write your inferences
df[df['dislikes']==df['dislikes'].max()]
# Out:
#           video_id                                title  \
# 13591  M0O7lLe4SmA  Cuties | Official Trailer | Netflix
#
#                      channel_id channel_title        published_at  view_count  \
# 13591  UCWOA1ZGywLbqmigxE4Qlvuw       Netflix 2020-08-18 14:00:00    17996395
#
#        likes  dislikes  comment_count  \
# 13591  94569   2397733         205009
#
#                                                     tags  \
# 13591  Cuties Mignonnes Netflix NetflixFilm Dance Mai...
#
#                                              description  \
# 13591  Eleven-year-old Amy starts to rebel against he...
#
#                                                 comments published_month
# 13591  I love how the mom is the bad guy for not lett...          August

# %%
# Title of video with minimum dislikes
df[df['dislikes']==df['dislikes'].min()]
# Out:
#           video_id                                   title  \
# 29482  mFK01TbgDuo  Tims For Good: A Taste Of The Familiar
#
#                      channel_id channel_title        published_at  view_count  \
# 29482  UC_oe3z-MmiibqNtRvBKZQig   Tim Hortons 2021-01-26 21:39:04     1654486
#
#        likes  dislikes  comment_count                                  tags  \
# 29482     28         3             29  Tims For Good Tim Hortons healthcare
#
#                                              description  \
# 29482  The world has looked a little different, so we...
#
#                                                 comments published_month
# 29482  Man I love you Timmy's. Your the best coffee s...         January

# %%
# 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.
# plot a scatter plot between views and dislikes
plt.scatter(df['view_count'], df['dislikes'])
plt.xlabel('view_count')
plt.ylabel('dislikes')
plt.show()
# calculate the correlation coefficient between views and dislikes
df['view_count'].corr(df['dislikes'])
# Out:
# 0.6845758297072596

# %% [markdown]
# * A correlation coefficient of 0.6846 suggests a moderate positive correlation between the view_count and the number of dislikes.
# * It means that as the view count increases, the number of dislikes also tends to increase.
# * However, it is important to note that correlation coefficient value is very small, so we cannot conclude that views are causing dislikes or vice versa.
# * There may be other factors that are influencing both variables

# %%
# 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.
df.loc[df['published_month']=='January']
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
df.loc[df['published_month']=='January']['title'].count()
# Out:
# 2099
